# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("online_retail_cleaned.csv")

# Convert InvoiceDate to datetime
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# Top 10 products by Quantity
top_products_qty = df.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)

print("=== Top 10 Products by Quantity ===")
print(comparison)

plt.figure(figsize=(12,6))
top_products_qty.plot(kind='bar')
plt.title("Top 10 Products by Quantity")
plt.ylabel("Quantity Sold")
plt.show()

# Top 10 products by Revenue
top_products_rev = df.groupby('Description')['TotalPrice'].sum().sort_values(ascending=False).head(10)

print("=== Top 10 Products by Revenue ===")
print(top_products_rev)

plt.figure(figsize=(12,6))
top_products_rev.plot(kind='bar')
plt.title("Top 10 Products by Revenue")
plt.ylabel("Revenue")
plt.show()

# Merge for comparison
comparison = pd.DataFrame({
    "Quantity": top_products_qty,
    "Revenue": top_products_rev
}).fillna(0)

print("=== Comparison of Top Products by Quantity vs Revenue ===")
print(comparison)

# Plot side-by-side bars
comparison.plot(kind='bar', figsize=(14,6))
plt.title("Comparison: Top Products by Quantity vs Revenue")
plt.ylabel("Values (Qty / Revenue)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# === Top 10 Products by Quantity ===
#                                     Quantity    Revenue
# Description
# 60 TEATIME FAIRY CAKE CASES          53495.0       0.00
# ASSORTED COLOUR BIRD ORNAMENT        79913.0  127074.17
# BLACK RECORD COVER FRAME                 0.0   67209.44
# BROCADE RING PURSE                   71129.0       0.00
# CHILLI LIGHTS                            0.0   72860.14
# JUMBO BAG RED RETROSPOT              75759.0  136980.08
# MEDIUM CERAMIC TOP STORAGE JAR       77916.0   81416.73
# PACK OF 60 PINK PAISLEY CAKE CASES   55270.0       0.00
# PACK OF 72 RETROSPOT CAKE CASES      46107.0       0.00
# PAPER CHAIN KIT 50'S CHRISTMAS           0.0   79594.33
# PAPER CRAFT , LITTLE BIRDIE          80995.0  168469.60
# PARTY BUNTING                            0.0  103880.23
# REGENCY CAKESTAND 3 TIER                 0.0  286486.30
# WHITE HANGING HEART T-LIGHT HOLDER   93640.0  252072.46
# WORLD WAR 2 GLIDERS ASSTD DESIGNS   109169.0       0.00
# === Top 10 Products by Revenue ===
# Description
# REGENCY CAKESTAND 3 TIER              286486.30
# WHITE HANGING HEART T-LIGHT HOLDER    252072.46
# PAPER CRAFT , LITTLE BIRDIE           168469.60
# JUMBO BAG RED RETROSPOT               136980.08
# ASSORTED COLOUR BIRD ORNAMENT         127074.17
# PARTY BUNTING                         103880.23
# MEDIUM CERAMIC TOP STORAGE JAR         81416.73
# PAPER CHAIN KIT 50'S CHRISTMAS         79594.33
# CHILLI LIGHTS                          72860.14
# BLACK RECORD COVER FRAME               67209.44
# Name: TotalPrice, dtype: float64
# === Comparison of Top Products by Quantity vs Revenue ===
#                                     Quantity    Revenue
# Description
# 60 TEATIME FAIRY CAKE CASES          53495.0       0.00
# ASSORTED COLOUR BIRD ORNAMENT        79913.0  127074.17
# BLACK RECORD COVER FRAME                 0.0   67209.44
# BROCADE RING PURSE                   71129.0       0.00
# CHILLI LIGHTS                            0.0   72860.14
# JUMBO BAG RED RETROSPOT              75759.0  136980.08
# MEDIUM CERAMIC TOP STORAGE JAR       77916.0   81416.73
# PACK OF 60 PINK PAISLEY CAKE CASES   55270.0       0.00
# PACK OF 72 RETROSPOT CAKE CASES      46107.0       0.00
# PAPER CHAIN KIT 50'S CHRISTMAS           0.0   79594.33
# PAPER CRAFT , LITTLE BIRDIE          80995.0  168469.60
# PARTY BUNTING                            0.0  103880.23
# REGENCY CAKESTAND 3 TIER                 0.0  286486.30
# WHITE HANGING HEART T-LIGHT HOLDER   93640.0  252072.46
# WORLD WAR 2 GLIDERS ASSTD DESIGNS   109169.0       0.00
