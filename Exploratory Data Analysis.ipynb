# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Load dataset
# df = pd.read_csv("online_retail_cleaned.csv")

# # Convert InvoiceDate to datetime
# df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# # Use existing TotalPrice column as Revenue
# df['Revenue'] = df['TotalPrice']   # already available

# # Extract Year + Month
# df['YearMonth'] = df['InvoiceDate'].dt.to_period('M')

# # Group by month
# monthly_revenue = df.groupby('YearMonth')['Revenue'].sum()

# # Plot
# plt.figure(figsize=(12,6))
# monthly_revenue.plot(kind='line', marker='o')
# plt.title("Monthly Revenue Trends")
# plt.xlabel("Month")
# plt.ylabel("Revenue")
# plt.xticks(rotation=45)
# plt.show()

# %%
# # Extract weekday & hour
# df['Weekday'] = df['InvoiceDate'].dt.day_name()  # e.g. Monday, Tuesday
# df['Hour'] = df['InvoiceDate'].dt.hour

# # Sales by Weekday
# weekday_sales = df.groupby('Weekday')['TotalPrice'].sum().reindex(
#     ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
# )

# plt.figure(figsize=(10,5))
# weekday_sales.plot(kind='bar')
# plt.title("Revenue by Weekday")
# plt.ylabel("Revenue")
# plt.show()

# # Sales by Hour
# hourly_sales = df.groupby('Hour')['TotalPrice'].sum()

# plt.figure(figsize=(10,5))
# hourly_sales.plot(kind='bar')
# plt.title("Revenue by Hour")
# plt.xlabel("Hour of Day")
# plt.ylabel("Revenue")
# plt.show()

# %%
# # Sales by Country
# country_sales = df.groupby('Country')['TotalPrice'].sum().sort_values(ascending=False)

# plt.figure(figsize=(12,6))
# country_sales[1:11].plot(kind='bar')  # skip UK to see top other countries
# plt.title("Top 10 Countries by Revenue (Excluding UK)")
# plt.ylabel("Revenue")
# plt.show()

# %%
# # Top 10 products by Quantity
# top_products_qty = df.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)

# plt.figure(figsize=(12,6))
# top_products_qty.plot(kind='bar')
# plt.title("Top 10 Products by Quantity")
# plt.ylabel("Quantity Sold")
# plt.show()

# # Top 10 products by Revenue
# top_products_rev = df.groupby('Description')['TotalPrice'].sum().sort_values(ascending=False).head(10)

# plt.figure(figsize=(12,6))
# top_products_rev.plot(kind='bar')
# plt.title("Top 10 Products by Revenue")
# plt.ylabel("Revenue")
# plt.show()
